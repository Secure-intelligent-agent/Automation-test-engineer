# %% [markdown]
# # Basic Python Commands Required For Automation Testing
# ---CMD-----
# py.test
#
#
# py.test --capture=no <file-name.py>
# -------------------------------------------------
#
#
#
# -----------------------------------------
# test files of python
#
# 1)driver path location is to be changed.
# 2)self.driver in the action(function).
# 3)element( 0 , 0)
# need to remove  0,0 from the code.
#
#
#
# -----------------------------------------
#
#
# Running pytest
# To run pytest, the following two calls are identical:
# --------------------------------------------------------------------
# python -m pytest test_um_pytest.py
# py.test test_um_pytest.py
#
# 1
# 2
# 3
#
# --------------------------------------------
#
# python -m pytest test_um_pytest.py
# py.test test_um_pytest.py
#
# --------------------------------------------
#
#
# for showing bar graph of the test cases 0 to 100% :
# ----------------------------------------------------------------
# pip install pytest-sugar
# pip install pytest-xdist 1.14
#
# -------------------------------------------------
#
#
# For genrating HTML Report for Test Performed.
# --------------------------------------
#
# pip install pytest-html
#
#
# for running test cases more than once
# -----------------------------------------------------
#
# pip install pytest-repeat
#
# py.test --count=10 test_file.py
#
#
# ----------------------------------------------------------
# for finding the intermittant failure
# ------------------------------------------------------------
#
# py.test --count=1000 -x test_file.py
#
#
# --------------------------------------------------------
# for finding the py test sugar plugin
# -----------------------------------------------------------
# py.test
#
#
# for robot framework
# -----------------------------------------------------------
# run : pip install robotframework
#
# ---------------------------------------------------------
# pytest to slack notification
# ------------------------------------------------------------
#
# pip install pytest-slack
#
#
#
# --------------------------------------------------------
# #  Head-less execution or .py application( .exe)
# python .exe file executor
#
# pip install pyinstaller
#
# pyinstaller --onefile <your_script_name>.py
#
# _________________________________________________________
#
#  for warning
# pip install pytest-warnings
# if you then type:
#
# py.test -rw
